# %%
import numpy as np

# %%
P = np.array([[0.1,0.4,0.5],[0.1,0.7,0.2],[0.5,0.2,0.3]])
# X = np.array([0.1,0.3,0.5])
# np.dot(X,P)
for i in range(100):
    P = np.dot(P,P)
    print(P)
# Out:
# [[0.3  0.42 0.28]
#  [0.18 0.57 0.25]
#  [0.22 0.4  0.38]]
# [[0.2272 0.4774 0.2954]
#  [0.2116 0.5005 0.2879]
#  [0.2216 0.4724 0.306 ]]
# [[0.21809832 0.48695094 0.29495074]
#  [0.21777996 0.48752205 0.29469799]
#  [0.21811696 0.48678244 0.2951006 ]]
# [[0.21794879 0.48717934 0.29487186]
#  [0.21794861 0.48717971 0.29487168]
#  [0.21794885 0.48717922 0.29487193]]
# [[0.21794872 0.48717949 0.29487179]
#  [0.21794872 0.48717949 0.29487179]
#  [0.21794872 0.48717949 0.29487179]]
# [[0.21794872 0.48717949 0.29487179]
#  [0.21794872 0.48717949 0.29487179]
#  [0.21794872 0.48717949 0.29487179]]
# [[0.21794872 0.48717949 0.29487179]
#  [0.21794872 0.48717949 0.29487179]
#  [0.21794872 0.48717949 0.29487179]]
# [[0.21794872 0.48717949 0.29487179]
#  [0.21794872 0.48717949 0.29487179]
#  [0.21794872 0.48717949 0.29487179]]
# [[0.21794872 0.48717949 0.29487179]
#  [0.21794872 0.48717949 0.29487179]
#  [0.21794872 0.48717949 0.29487179]]
# [[0.21794872 0.48717949 0.29487179]
# ...
